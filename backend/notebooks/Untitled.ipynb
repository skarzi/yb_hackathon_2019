# %%
import torch 
precision = 'fp32'
map_location = torch.device('cpu')
ssd_model = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_ssd', model_math=precision, map_location='cuda:0')
# Out:
# Using cache found in /home/matt/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-18147721e658> in <module>
#       2 precision = 'fp32'
#       3 map_location = torch.device('cpu')
# ----> 4 ssd_model = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_ssd', model_math=precision, map_location='cuda:0')
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/hub.py in load(github, model, *args, **kwargs)
#     357     entry = _load_entry_from_hubconf(hub_module, model)
#     358
# --> 359     model = entry(*args, **kwargs)
#     360
#     361     sys.path.remove(repo_dir)
#
# ~/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/hubconf.py in nvidia_ssd(pretrained, **kwargs)
#     364             checkpoint = 'https://developer.nvidia.com/joc-ssd-fp32-pyt-20190225'
#     365         ckpt_file = _download_checkpoint(checkpoint, force_reload)
# --> 366         ckpt = torch.load(ckpt_file)
#     367         ckpt = ckpt['model']
#     368         if checkpoint_from_distributed(ckpt):
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     424         if sys.version_info >= (3, 0) and 'encoding' not in pickle_load_args.keys():
#     425             pickle_load_args['encoding'] = 'utf-8'
# --> 426         return _load(f, map_location, pickle_module, **pickle_load_args)
#     427     finally:
#     428         if new_fd:
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in _load(f, map_location, pickle_module, **pickle_load_args)
#     611     unpickler = pickle_module.Unpickler(f, **pickle_load_args)
#     612     unpickler.persistent_load = persistent_load
# --> 613     result = unpickler.load()
#     614
#     615     deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in persistent_load(saved_id)
#     574                 obj = data_type(size)
#     575                 obj._torch_load_uninitialized = True
# --> 576                 deserialized_objects[root_key] = restore_location(obj, location)
#     577             storage = deserialized_objects[root_key]
#     578             if view_metadata is not None:
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in default_restore_location(storage, location)
#     153 def default_restore_location(storage, location):
#     154     for _, _, fn in _package_registry:
# --> 155         result = fn(storage, location)
#     156         if result is not None:
#     157             return result
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in _cuda_deserialize(obj, location)
#     129 def _cuda_deserialize(obj, location):
#     130     if location.startswith('cuda'):
# --> 131         device = validate_cuda_device(location)
#     132         if getattr(obj, "_torch_load_uninitialized", False):
#     133             storage_type = getattr(torch.cuda, type(obj).__name__)
#
# ~/code/yb_hackathon_2019/backend/my_env/lib/python3.7/site-packages/torch/serialization.py in validate_cuda_device(location)
#     113
#     114     if not torch.cuda.is_available():
# --> 115         raise RuntimeError('Attempting to deserialize object on a CUDA '
#     116                            'device but torch.cuda.is_available() is False. '
#     117                            'If you are running on a CPU-only machine, '
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
utils = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_ssd_processing_utils')
